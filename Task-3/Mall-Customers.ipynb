# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Mall_Customers.csv")
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe().T
# Out:
#                         count    mean        std   min    25%    50%     75%  \
# CustomerID              200.0  100.50  57.879185   1.0  50.75  100.5  150.25
# Age                     200.0   38.85  13.969007  18.0  28.75   36.0   49.00
# Annual Income (k$)      200.0   60.56  26.264721  15.0  41.50   61.5   78.00
# Spending Score (1-100)  200.0   50.20  25.823522   1.0  34.75   50.0   73.00
#
#                           max
# CustomerID              200.0
# Age                      70.0
# Annual Income (k$)      137.0
# Spending Score (1-100)   99.0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df.Gender.value_counts()
# Out:
# Female    112
# Male       88
# Name: Gender, dtype: int64

# %%
df.Gender.value_counts().plot(kind='bar',title='Gender Bar Chat',figsize=(8,8),color=['red','blue'])
plt.show()

# %%
df.Gender.value_counts().plot(kind='pie',autopct='%1.0f%%',title='Gender Pie Chat', figsize=(8,8))
plt.show()

# %%
df.Age.plot(kind='kde',title='Age Distribution Plot',figsize=(8,6))
plt.show()

# %%
df.Age.plot(kind='box',title='Age of box chart',figsize=(8,6))
plt.show()

# %%
df.head(1)
# Out:
#    CustomerID Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1   Male   19                  15                      39

# %%
df['Annual Income (k$)'].max()
# Out:
# 137

# %%
df['Annual Income (k$)'].min()
# Out:
# 15

# %%
df['Annual Income (k$)'].plot(kind='kde',title='Annual Income of Distribution Plot',figsize=(8,6))
plt.show()

# %%
df['Annual Income (k$)'].plot(kind='box',title='Annual Income of Box Plot',figsize=(8,6))
plt.show()

# %%
df=df[df['Annual Income (k$)']<120]

# %%
df.shape
# Out:
# (194, 4)

# %%
# df.drop(columns='CustomerID',inplace=True)

# %%
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0    Male   19                  15                      39
# 1    Male   21                  15                      81
# 2  Female   20                  16                       6
# 3  Female   23                  16                      77
# 4  Female   31                  17                      40

# %%
df['Annual Income (k$)'].plot(kind='box',title='Annual Income of Box Plot',figsize=(8,6))
plt.show()

# %%
df['Spending Score (1-100)'].plot(kind='kde',title='Spending Score of Distribution Plot',figsize=(8,6))
plt.show()

# %%
df['Spending Score (1-100)'].plot(kind='box',title='Spending Score of box Plot',figsize=(8,6))
plt.show()

# %% [markdown]
# ### BiVariant Analysis

# %%
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0    Male   19                  15                      39
# 1    Male   21                  15                      81
# 2  Female   20                  16                       6
# 3  Female   23                  16                      77
# 4  Female   31                  17                      40

# %%
df.plot(kind='scatter',x='Age',y='Annual Income (k$)')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Age',y='Annual Income (k$)',hue='Gender',data=df)
plt.show()

# %%
df.plot(kind='scatter',x='Age',y='Spending Score (1-100)')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Age',y='Spending Score (1-100)',hue='Gender',data=df)
plt.show()

# %%
df.plot(kind='scatter',x='Gender',y='Annual Income (k$)')
plt.show()

# %% [markdown]
# ### Multi-Variant Analysis

# %%
import plotly.express as px
plt.figure(figsize=(8,6))
fig = px.scatter_3d(df,x='Age',y='Annual Income (k$)',z='Spending Score (1-100)',color='Gender')
fig.show()
